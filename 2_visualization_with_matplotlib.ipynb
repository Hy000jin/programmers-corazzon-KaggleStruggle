# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import numpy as np

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # Load data

# %%
data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([ -40,  -62,  -44,  -96, -122, -208, -135, -172, -139, -152, -130,
#        -223, -303, -370, -313, -231, -279, -376, -437, -475, -492, -495,
#        -441, -523, -492, -452, -370, -464, -456, -493, -440, -349, -352,
#        -429, -436, -383, -390, -478, -555, -602, -511, -500, -470, -498,
#        -453, -367, -276, -332, -260, -170], dtype=int32)

# %% [markdown]
# # Visualization with hangul

# %%
plt.plot(range(50), data, 'g')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5,0,'시간(분)')

# %% [markdown]
# # Error handling to fix Problem with hangul

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  2.2.2
# 설치 위치:  C:\Users\hyooo\Anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\hyooo\.matplotlib
# 캐시 위치:  C:\Users\hyooo\.matplotlib

# %%
print ('설정 파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정 파일 위치:  C:\Users\hyooo\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
# ttf 폰트 전체개수
print(len(font_list))
# Out:
# 1070

# %%
font_list_mac = fm.OSXInstalledFonts()
print(len(font_list_mac))
# Out:
# 0

# %%
font_list[:10]
# Out:
# ['C:\\WINDOWS\\Fonts\\ARIALNI.TTF',
#  'C:\\WINDOWS\\Fonts\\corbel.ttf',
#  'c:\\windows\\fonts\\hygsrb.ttf',
#  'C:\\WINDOWS\\Fonts\\ENHOBO.TTF',
#  'C:\\WINDOWS\\Fonts\\FRSCRIPT.TTF',
#  'C:\\WINDOWS\\Fonts\\ENFREEHD.TTF',
#  'c:\\windows\\fonts\\wingdng3.ttf',
#  'c:\\windows\\fonts\\imprisha.ttf',
#  'C:\\WINDOWS\\Fonts\\YMAE07.TTF',
#  'c:\\program files (x86)\\ibm\\spss\\statistics\\21\\jre\\lib\\fonts\\lucidasansregular.ttf']

# %%
f = [f.name for f in fm.fontManager.ttflist]
print(len(font_list))
# 10개의 폰트 명 만 출력
f[:10]
# Out:
# 1070
# ['DejaVu Sans Mono',
#  'DejaVu Serif',
#  'cmmi10',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'cmtt10',
#  'DejaVu Sans Mono',
#  'cmsy10']

# %%
# 나눔고딕만 들어간 폰트
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumMyeongjo', 'C:\\WINDOWS\\Fonts\\나눔명조.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\나눔고딕_0.ttf'),
#  ('NanumGothic', 'c:\\windows\\fonts\\나눔고딕bold.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\나눔고딕.ttf'),
#  ('NanumMyeongjo', 'C:\\WINDOWS\\Fonts\\나눔명조Bold.ttf'),
#  ('NanumMyeongjo', 'c:\\windows\\fonts\\나눔명조bold.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\나눔고딕Bold.ttf')]

# %% [markdown]
# ## 폰트 사용하기 3가지 방법

# %% [markdown]
# ### 1. FontProperties 사용하는 방법

# %%
path = 'c:\\windows\\fonts\\나눔고딕bold.ttf'
fontprop = fm.FontProperties(fname=path, size=10)

plt.plot(range(50), data, 'g')
plt.title('시간별 가격 추이', fontproperties=fontprop)
plt.ylabel('주식 가격', fontproperties=fontprop)
plt.xlabel('시간(분)', fontproperties=fontprop)
plt.show()

# %% [markdown]
# ### 2.matplotlib.rcParams[]으로 전역 글꼴 설정 방법

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print('# 설정되어있는 폰트 사이즈')
print (plt.rcParams['font.size'] ) 
print('# 설정되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )
# Out:
# # 설정되어있는 폰트 사이즈
# 10.0
# # 설정되어있는 폰트 글꼴
# ['sans-serif']

# %%
# serif, sans-serif, monospace
print('serif 세리프가 있는 폰트--------')
print (plt.rcParams['font.serif']) 
print('sans-serif 세리프가 없는 폰트 --------')
print (plt.rcParams['font.sans-serif']) 
print('monospace 고정폭 글꼴--------')
print (plt.rcParams['font.monospace'])
# Out:
# serif 세리프가 있는 폰트--------
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# sans-serif 세리프가 없는 폰트 --------
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# monospace 고정폭 글꼴--------
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
plt.rcParams["font.family"] = 'NanumMyeongjo'
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (14,4)

# %%
plt.plot(range(50), data, 'g')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('seaborn-pastel')
plt.show()

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print('# 설정되어있는 폰트 사이즈')
print (plt.rcParams['font.size'] ) 
print('# 설정되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )
# Out:
# # 설정되어있는 폰트 사이즈
# 20.0
# # 설정되어있는 폰트 글꼴
# ['NanumMyeongjo']

# %%
plt.rcParams["font.family"] = 'sans-serif'
plt.rcParams["font.size"] = 10
plt.rcParams["figure.figsize"] = (14,4)

# %%
# rcParams 대신 FontProperties와 plt.rc를 사용하는 방법
path = 'C:\\WINDOWS\\Fonts\\나눔고딕Bold.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
print(font_name)
plt.rc('font', family=font_name)

fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('ggplot')
plt.show()
# Out:
# NanumGothic

# %% [markdown]
# ### 3. rcParams를 설정 파일에 직접 적어주는 방법 - 모든 노트북에 공통적용

# %%
print ('설정 파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정 파일 위치:  C:\Users\hyooo\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도 보기')
plt.show()
